# %%
import os
os.chdir("..")
print(os.getcwd())
# Out:
# /Users/isaac/Documents/GitHub/Macsum-aggregation-learning---Stage-LIP6--

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.metrics import mean_squared_log_error
from Code.Torsh.TorchMacsumAggregationLearning import *
from Code.Torsh.Torsh_data_generation import *
import torch.nn.functional as F
from Code.Torsh.NetowrkMacsum import MacsumNetWithActivation
from catboost import CatBoostClassifier, Pool

# %load_ext autoreload
# %autoreload 2
# Out:
# Using device: cpu

# %%
df = pd.read_csv("train.csv")
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
Y = df['Calories'].to_numpy()
df = df.drop(columns=['id','Calories'])
X = df.to_numpy()
print(X.shape)
print(X[:5],Y[:5])
# Out:
# (750000, 7)
# [[  0.   36.  189.   82.   26.  101.   41. ]
#  [  1.   64.  163.   60.    8.   85.   39.7]
#  [  1.   51.  161.   64.    7.   84.   39.8]
#  [  0.   20.  192.   90.   25.  105.   40.7]
#  [  1.   38.  166.   61.   25.  102.   40.6]] [150.  34.  29. 140. 146.]

# %%
model = MacsumSigmoidTorch(X.shape[1],alpha=0.1,gamma = 0.8,k_sigmoid=0.1)
model.fit_adam(X[:10000],Y[:10000],X[10001:11000],Y[10001:11000],learning_rate=1e-3,epsilon_conv=1e-6,n_epochs = 1000,beta1=0.8,beta2=0.99,batch_size=256)
# Out:
# Starting PyTorch Adam training (MacsumSigmoidTorch with Manual Gradient for Phi)...
# Adam Training (MacsumSigmoidTorch Manual Grad):  26%|██▌       | 259/1000 [00:06<00:19, 38.68it/s]Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10324c2b0>>
# Traceback (most recent call last):
#   File "/Users/isaac/Library/Python/3.9/lib/python/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Adam Training (MacsumSigmoidTorch Manual Grad):  68%|██████▊   | 676/1000 [00:18<00:09, 35.76it/s]

# %%
model = MacsumNetWithActivation([7,10,10,1],model_class= MacsumSigmoidTorch,activation_fn=F.gelu,alpha=0.1,gamma = 0.8,k_sigmoid=0.1)
model.fit_autograd(X[:10000],Y[:10000],X[10001:11000],Y[10001:11000],learning_rate=1e-3,epsilon_conv=1e-6,n_epochs =  500,beta1=0.8,beta2=0.99,batch_size=256)
# Out:
# Création d'un MacsumNet avec la fonction d'activation: gelu
# Starting PyTorch Autograd training for MacsumNet...
# Autograd Training (MacsumNet):  36%|███▌      | 180/500 [01:02<01:50,  2.90it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 model = MacsumNetWithActivation([7,10,10,1],model_class= MacsumSigmoidTorch,activation_fn=F.gelu,alpha=0.1,gamma = 0.8,k_sigmoid=0.1)
# ----> 2 model.fit_autograd(X[:10000],Y[:10000],X[10001:11000],Y[10001:11000],learning_rate=1e-3,epsilon_conv=1e-6,n_epochs =  500,beta1=0.8,beta2=0.99,batch_size=256)
#
# File ~/Documents/GitHub/Macsum-aggregation-learning---Stage-LIP6--/Code/Torsh/NetowrkMacsum.py:181, in MacsumNet.fit_autograd(self, X_train, Y_train, X_eval, Y_eval, learning_rate, n_epochs, batch_size, beta1, beta2, print_every, weight_decay, epsilon_conv)
#     178 optimizer.zero_grad()
#     180 # 1. Forward pass
# --> 181 y_lower_pred, y_upper_pred = self(X_batch)
#     183 # 2. Calculer la loss (utilise la fonction de coût de la classe parente)
#     184 loss_per_sample = self._loss(Y_batch, (y_lower_pred, y_upper_pred))
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Documents/GitHub/Macsum-aggregation-learning---Stage-LIP6--/Code/Torsh/NetowrkMacsum.py:245, in MacsumNetWithActivation.forward(self, x)
#     242 # On itère sur toutes les couches
#     243 for i, layer in enumerate(self.layers):
#     244     # 1. Passe à travers la couche Macsum
# --> 245     x_interval = layer(x_interval)
#     247     # 2. Appliquer la fonction d'activation si ce N'EST PAS la dernière couche
#     248     if self.activation_fn is not None and i < num_layers - 1:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Documents/GitHub/Macsum-aggregation-learning---Stage-LIP6--/Code/Torsh/NetowrkMacsum.py:53, in MacsumLayer.forward(self, x_interval)
#      50     all_y_lower.append(y_l_unit)
#      52     # y_upper_pred pour x_upper donne la borne sup de la sortie de cette unité
# ---> 53     _, y_u_unit = unit(x_upper)
#      54     all_y_upper.append(y_u_unit)
#      56 # Empile les résultats pour former des vecteurs de sortie
#      57 # Shape: (batch_size, out_features)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Documents/GitHub/Macsum-aggregation-learning---Stage-LIP6--/Code/Torsh/TorchMacsumAggregationLearning.py:60, in Macsum.forward(self, x)
#      56 # --- CALCULS FAITS À LA VOLÉE DANS FORWARD ---
#      57 # 1. Calculer les permutations (traitées comme des constantes par autograd)
#      58 # On utilise un bloc no_grad pour être explicite que le tri ne doit pas avoir de gradient.
#      59 with torch.no_grad():
# ---> 60     perm_decreasing = torch.argsort(self._phi, descending=True).long()
#      62 # 2. Calculer phi_plus et phi_minus EN GARDANT LA CONNEXION AU GRAPHE
#      63 # On n'utilise PAS .data ou .detach() ici !
#      64 phi_plus = torch.clamp_min(self._phi, 0)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1698, in Module.__getattr__(self, name)
#    1696 def __getattr__(self, name: str) -> Any:
#    1697     if '_parameters' in self.__dict__:
# -> 1698         _parameters = self.__dict__['_parameters']
#    1699         if name in _parameters:
#    1700             return _parameters[name]
#
# KeyboardInterrupt:

# %% [markdown]
# ### nb data

# %%
#l=[]
#for i in range(1,51):
#    model = MacsumSigmoidTorch(X.shape[1],alpha=0.1,gamma=0.8,k_sigmoid=0.1)
#    model.fit_adam(X[:i*100],Y[:i*100],learning_rate=1e-3,epsilon_conv=1e-6,n_epochs = 1000,beta1=0.8,beta2=0.99,batch_size=256)
#    l.append(evaluate_model_complet(X[10000:],Y[10000:],model)["containment_rate"])
#plt.plot(l)
#plt.title("plot en fonction du nombre 100 ete d'exemple")
#plt.xlabel("nombr d'exemple dans le data set * 100")
#plt.ylabel("Valeur")
#plt.grid(True)
#plt.show()

# %%
i= [ 300000,300005 , 30000]
print(Y[i])
model.forward( torch.tensor(X[i], dtype=torch.float64))
# Out:
# [60. 67. 40.]
# (tensor([ -9.2391, -19.3941, -38.2837], dtype=torch.float64,
#         grad_fn=<SqueezeBackward1>),
#  tensor([153.7746, 159.3695, 136.5691], dtype=torch.float64,
#         grad_fn=<SqueezeBackward1>))

# %%
print(evaluate_model_complet(X,Y,model))
print(np.mean(Y))
# Out:
# {'containment_rate': 0.9999666666666667, 'avg_misp_distance': 23.171367770027622, 'avg_eval_loss': 20.68247605428054, 'avg_train_loss': nan, 'avg_interval_spread': 182.2628784655429, 'median_interval_spread': 177.18980489496582, 'q95_interval_spread': 223.98897887031404, 'phi_distance_l2_normal': None}
# 88.28278133333333

# %%
plot_metrics_complet([model.history,model.history])

# %%
# Conversion de X en tenseur torch
X_tensor = torch.tensor(X, dtype=torch.float64)
# Appel du modèle une seule fois
tops, bots = model.forward(X_tensor) 
tops = tops.detach().numpy()
bots = bots.detach().numpy()
# Moyenne élément par élément
Y_pred = ((tops + bots) / 2)
Y_pred_bot,Y_pred_top = tops,bots
print(Y_pred,Y_pred_bot,Y_pred_top)
# Out:
# [134.01831268  28.91824367  22.11805623 ... 190.86611915 109.59969948
#   95.21304955] [ 46.56274676 -59.53095516 -67.62339691 ...  63.40726121  17.09979702
#   11.46098311] [221.47387861 117.3674425  111.85950937 ... 318.3249771  202.09960194
#  178.96511599]

# %%
rmsle = np.sqrt( mean_squared_log_error(Y, abs(Y_pred)))
rmsle_t = np.sqrt(mean_squared_log_error(Y, abs(Y_pred_top)))
rmsle_b = np.sqrt(mean_squared_log_error(Y, abs(Y_pred_bot)))
print("RMSLE =", rmsle,rmsle_b,rmsle_t)
# Out:
# RMSLE = 0.31735113544589566 1.5651054581361352 1.162579552335557

# %%
model = CatBoostClassifier(iterations=1000, verbose=10)
model.fit(X[:5000],Y[:5000], eval_set=(X[:5001], Y[:5001]))
print(model.predict(X[0]))
# Out:
# Learning rate set to 0.111508
# 0:	learn: 5.4850126	test: 5.4849433	best: 5.4849433 (0)	total: 120ms	remaining: 2m
# 10:	learn: 4.5913112	test: 4.5910350	best: 4.5910350 (10)	total: 1.31s	remaining: 1m 58s
# 20:	learn: 4.1733110	test: 4.1729760	best: 4.1729760 (20)	total: 2.58s	remaining: 2m
# 30:	learn: 3.8983302	test: 3.8980102	best: 3.8980102 (30)	total: 3.95s	remaining: 2m 3s
# 40:	learn: 3.6800407	test: 3.6797314	best: 3.6797314 (40)	total: 5.33s	remaining: 2m 4s
# 50:	learn: 3.5330747	test: 3.5328003	best: 3.5328003 (50)	total: 6.84s	remaining: 2m 7s
# 60:	learn: 3.3772500	test: 3.3769996	best: 3.3769996 (60)	total: 8.34s	remaining: 2m 8s
# 70:	learn: 3.2359398	test: 3.2357096	best: 3.2357096 (70)	total: 9.84s	remaining: 2m 8s
# 80:	learn: 3.1343508	test: 3.1341275	best: 3.1341275 (80)	total: 11.4s	remaining: 2m 9s
# 90:	learn: 3.0410450	test: 3.0408366	best: 3.0408366 (90)	total: 12.9s	remaining: 2m 8s
# 100:	learn: 2.9537730	test: 2.9535816	best: 2.9535816 (100)	total: 14.4s	remaining: 2m 8s
# 110:	learn: 2.8783321	test: 2.8781550	best: 2.8781550 (110)	total: 15.9s	remaining: 2m 7s
# 120:	learn: 2.8218675	test: 2.8217140	best: 2.8217140 (120)	total: 17.5s	remaining: 2m 7s
# 130:	learn: 2.7664255	test: 2.7662835	best: 2.7662835 (130)	total: 19s	remaining: 2m 5s
# 140:	learn: 2.6990166	test: 2.6988828	best: 2.6988828 (140)	total: 20.5s	remaining: 2m 4s
# 150:	learn: 2.6406318	test: 2.6405162	best: 2.6405162 (150)	total: 21.9s	remaining: 2m 3s
# 160:	learn: 2.5867286	test: 2.5866166	best: 2.5866166 (160)	total: 23.3s	remaining: 2m 1s
# 170:	learn: 2.5344859	test: 2.5343928	best: 2.5343928 (170)	total: 24.8s	remaining: 2m
# 180:	learn: 2.4977067	test: 2.4976246	best: 2.4976246 (180)	total: 26.2s	remaining: 1m 58s
# 190:	learn: 2.4446235	test: 2.4445496	best: 2.4445496 (190)	total: 27.7s	remaining: 1m 57s
# 200:	learn: 2.3893557	test: 2.3892967	best: 2.3892967 (200)	total: 29.1s	remaining: 1m 55s
# 210:	learn: 2.3476710	test: 2.3476184	best: 2.3476184 (210)	total: 30.7s	remaining: 1m 54s
# 220:	learn: 2.3018206	test: 2.3017795	best: 2.3017795 (220)	total: 32.2s	remaining: 1m 53s
# 230:	learn: 2.2625740	test: 2.2625401	best: 2.2625401 (230)	total: 33.6s	remaining: 1m 51s
# 240:	learn: 2.2147508	test: 2.2147272	best: 2.2147272 (240)	total: 35s	remaining: 1m 50s
# 250:	learn: 2.1720229	test: 2.1720081	best: 2.1720081 (250)	total: 36.5s	remaining: 1m 48s
# 260:	learn: 2.1306047	test: 2.1306123	best: 2.1306123 (260)	total: 37.9s	remaining: 1m 47s
# 270:	learn: 2.0998813	test: 2.0998948	best: 2.0998948 (270)	total: 39.3s	remaining: 1m 45s
# 280:	learn: 2.0611506	test: 2.0611750	best: 2.0611750 (280)	total: 40.7s	remaining: 1m 44s
# 290:	learn: 2.0243985	test: 2.0244348	best: 2.0244348 (290)	total: 42.1s	remaining: 1m 42s
# 300:	learn: 1.9850488	test: 1.9850887	best: 1.9850887 (300)	total: 43.6s	remaining: 1m 41s
# 310:	learn: 1.9510548	test: 1.9510985	best: 1.9510985 (310)	total: 45s	remaining: 1m 39s
# 320:	learn: 1.9092670	test: 1.9093265	best: 1.9093265 (320)	total: 46.5s	remaining: 1m 38s
# 330:	learn: 1.8793583	test: 1.8794219	best: 1.8794219 (330)	total: 47.9s	remaining: 1m 36s
# 340:	learn: 1.8457175	test: 1.8457878	best: 1.8457878 (340)	total: 49.3s	remaining: 1m 35s
# 350:	learn: 1.8048859	test: 1.8049752	best: 1.8049752 (350)	total: 50.7s	remaining: 1m 33s
# 360:	learn: 1.7708868	test: 1.7709859	best: 1.7709859 (360)	total: 52.2s	remaining: 1m 32s
# 370:	learn: 1.7394133	test: 1.7395139	best: 1.7395139 (370)	total: 53.6s	remaining: 1m 30s
# 380:	learn: 1.7058803	test: 1.7059906	best: 1.7059906 (380)	total: 55.1s	remaining: 1m 29s
# 390:	learn: 1.6738886	test: 1.6740137	best: 1.6740137 (390)	total: 56.5s	remaining: 1m 28s
# 400:	learn: 1.6385247	test: 1.6386628	best: 1.6386628 (400)	total: 58s	remaining: 1m 26s
# 410:	learn: 1.6076890	test: 1.6078367	best: 1.6078367 (410)	total: 59.4s	remaining: 1m 25s
# 420:	learn: 1.5766991	test: 1.5768603	best: 1.5768603 (420)	total: 1m	remaining: 1m 23s
# 430:	learn: 1.5471188	test: 1.5472845	best: 1.5472845 (430)	total: 1m 2s	remaining: 1m 22s
# 440:	learn: 1.5182530	test: 1.5184237	best: 1.5184237 (440)	total: 1m 3s	remaining: 1m 20s
# 450:	learn: 1.4884912	test: 1.4886650	best: 1.4886650 (450)	total: 1m 5s	remaining: 1m 19s
# 460:	learn: 1.4594028	test: 1.4595844	best: 1.4595844 (460)	total: 1m 6s	remaining: 1m 17s
# 470:	learn: 1.4302785	test: 1.4304676	best: 1.4304676 (470)	total: 1m 7s	remaining: 1m 16s
# 480:	learn: 1.4020225	test: 1.4022221	best: 1.4022221 (480)	total: 1m 9s	remaining: 1m 14s
# 490:	learn: 1.3739071	test: 1.3741089	best: 1.3741089 (490)	total: 1m 10s	remaining: 1m 13s
# 500:	learn: 1.3450901	test: 1.3453002	best: 1.3453002 (500)	total: 1m 12s	remaining: 1m 12s
# 510:	learn: 1.3186035	test: 1.3188207	best: 1.3188207 (510)	total: 1m 13s	remaining: 1m 10s
# 520:	learn: 1.2929047	test: 1.2931358	best: 1.2931358 (520)	total: 1m 15s	remaining: 1m 9s
# 530:	learn: 1.2678619	test: 1.2680995	best: 1.2680995 (530)	total: 1m 16s	remaining: 1m 7s
# 540:	learn: 1.2420823	test: 1.2423298	best: 1.2423298 (540)	total: 1m 18s	remaining: 1m 6s
# 550:	learn: 1.2170050	test: 1.2172662	best: 1.2172662 (550)	total: 1m 19s	remaining: 1m 4s
# 560:	learn: 1.1949817	test: 1.1952453	best: 1.1952453 (560)	total: 1m 21s	remaining: 1m 3s
# 570:	learn: 1.1700119	test: 1.1702759	best: 1.1702759 (570)	total: 1m 22s	remaining: 1m 2s
# 580:	learn: 1.1428137	test: 1.1430903	best: 1.1430903 (580)	total: 1m 24s	remaining: 1m
# 590:	learn: 1.1217750	test: 1.1220529	best: 1.1220529 (590)	total: 1m 25s	remaining: 59.3s
# 600:	learn: 1.1026648	test: 1.1029394	best: 1.1029394 (600)	total: 1m 27s	remaining: 57.8s
# 610:	learn: 1.0817553	test: 1.0820456	best: 1.0820456 (610)	total: 1m 28s	remaining: 56.3s
# 620:	learn: 1.0587909	test: 1.0590888	best: 1.0590888 (620)	total: 1m 29s	remaining: 54.9s
# 630:	learn: 1.0389016	test: 1.0391967	best: 1.0391967 (630)	total: 1m 31s	remaining: 53.5s
# 640:	learn: 1.0200543	test: 1.0203499	best: 1.0203499 (640)	total: 1m 32s	remaining: 52s
# 650:	learn: 1.0014593	test: 1.0017656	best: 1.0017656 (650)	total: 1m 34s	remaining: 50.6s
# 660:	learn: 0.9833077	test: 0.9836112	best: 0.9836112 (660)	total: 1m 35s	remaining: 49.2s
# 670:	learn: 0.9661307	test: 0.9664443	best: 0.9664443 (670)	total: 1m 37s	remaining: 47.7s
# 680:	learn: 0.9477613	test: 0.9480752	best: 0.9480752 (680)	total: 1m 38s	remaining: 46.3s
# 690:	learn: 0.9289862	test: 0.9293030	best: 0.9293030 (690)	total: 1m 40s	remaining: 44.8s
# 700:	learn: 0.9148359	test: 0.9151516	best: 0.9151516 (700)	total: 1m 41s	remaining: 43.4s
# 710:	learn: 0.8976635	test: 0.8979871	best: 0.8979871 (710)	total: 1m 43s	remaining: 41.9s
# 720:	learn: 0.8812765	test: 0.8816071	best: 0.8816071 (720)	total: 1m 44s	remaining: 40.5s
# 730:	learn: 0.8652743	test: 0.8656070	best: 0.8656070 (730)	total: 1m 45s	remaining: 39s
# 740:	learn: 0.8485195	test: 0.8488632	best: 0.8488632 (740)	total: 1m 47s	remaining: 37.6s
# 750:	learn: 0.8332945	test: 0.8336366	best: 0.8336366 (750)	total: 1m 49s	remaining: 36.2s
# 760:	learn: 0.8171477	test: 0.8174990	best: 0.8174990 (760)	total: 1m 50s	remaining: 34.8s
# 770:	learn: 0.8023688	test: 0.8027228	best: 0.8027228 (770)	total: 1m 52s	remaining: 33.3s
# 780:	learn: 0.7892773	test: 0.7896369	best: 0.7896369 (780)	total: 1m 53s	remaining: 31.9s
# 790:	learn: 0.7748821	test: 0.7752430	best: 0.7752430 (790)	total: 1m 55s	remaining: 30.4s
# 800:	learn: 0.7621943	test: 0.7625614	best: 0.7625614 (800)	total: 1m 56s	remaining: 29s
# 810:	learn: 0.7484892	test: 0.7488625	best: 0.7488625 (810)	total: 1m 58s	remaining: 27.5s
# 820:	learn: 0.7356921	test: 0.7360641	best: 0.7360641 (820)	total: 1m 59s	remaining: 26.1s
# 830:	learn: 0.7238454	test: 0.7242242	best: 0.7242242 (830)	total: 2m	remaining: 24.6s
# 840:	learn: 0.7118675	test: 0.7122528	best: 0.7122528 (840)	total: 2m 2s	remaining: 23.2s
# 850:	learn: 0.6997216	test: 0.7001089	best: 0.7001089 (850)	total: 2m 4s	remaining: 21.7s
# 860:	learn: 0.6890643	test: 0.6894494	best: 0.6894494 (860)	total: 2m 5s	remaining: 20.3s
# 870:	learn: 0.6778119	test: 0.6782046	best: 0.6782046 (870)	total: 2m 6s	remaining: 18.8s
# 880:	learn: 0.6649776	test: 0.6653699	best: 0.6653699 (880)	total: 2m 8s	remaining: 17.3s
# 890:	learn: 0.6544032	test: 0.6547985	best: 0.6547985 (890)	total: 2m 9s	remaining: 15.9s
# 900:	learn: 0.6439754	test: 0.6443742	best: 0.6443742 (900)	total: 2m 11s	remaining: 14.4s
# 910:	learn: 0.6338579	test: 0.6342571	best: 0.6342571 (910)	total: 2m 12s	remaining: 13s
# 920:	learn: 0.6235644	test: 0.6239674	best: 0.6239674 (920)	total: 2m 14s	remaining: 11.5s
# 930:	learn: 0.6144547	test: 0.6148673	best: 0.6148673 (930)	total: 2m 15s	remaining: 10.1s
# 940:	learn: 0.6046529	test: 0.6050674	best: 0.6050674 (940)	total: 2m 17s	remaining: 8.6s
# 950:	learn: 0.5951199	test: 0.5955428	best: 0.5955428 (950)	total: 2m 18s	remaining: 7.14s
# 960:	learn: 0.5860659	test: 0.5864907	best: 0.5864907 (960)	total: 2m 20s	remaining: 5.68s
# 970:	learn: 0.5765808	test: 0.5770102	best: 0.5770102 (970)	total: 2m 21s	remaining: 4.23s
# 980:	learn: 0.5670814	test: 0.5675105	best: 0.5675105 (980)	total: 2m 23s	remaining: 2.77s
# 990:	learn: 0.5584690	test: 0.5588964	best: 0.5588964 (990)	total: 2m 24s	remaining: 1.31s
# 999:	learn: 0.5509807	test: 0.5514163	best: 0.5514163 (999)	total: 2m 25s	remaining: 0us
#
# bestTest = 0.5514162661
# bestIteration = 999
#
# [150.]

# %%
Y_pred = [model.predict(x) for x in X]

# %%
rmsle = np.sqrt( mean_squared_log_error(Y, Y_pred))
rmsle_t =0# np.sqrt(mean_squared_log_error(Y, abs(Y_pred_top)))
rmsle_b = 0#np.sqrt(mean_squared_log_error(Y, abs(Y_pred_bot)))
print("RMSLE =", rmsle,rmsle_b,rmsle_t)
# Out:
# RMSLE = 0.12012726817998667 0 0

# %%
epsil = 1
Y_pred_b = np.array(Y_pred)-epsil
Y_pred_t= np.array(Y_pred)+epsil

# %%
rmsle = np.sqrt( mean_squared_log_error(Y, Y_pred))
rmsle_t =np.sqrt(mean_squared_log_error(Y, Y_pred_t))
rmsle_b = np.sqrt(mean_squared_log_error(Y, Y_pred_b))
print("RMSLE =", rmsle,rmsle_b,rmsle_t)
# Out:
# RMSLE = 0.12012726817998667 0.12958906620404004 0.12962638322642864
