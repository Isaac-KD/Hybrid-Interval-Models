# %% [markdown]
# ## Les imports

# %%
import numpy as np

from MacsumAggregationLearning import *
from typing import Tuple

import csv
import pandas as pd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Géneration des données

# %%
N = 2
# C'est le vrai noyau que l'on va essayer de retrouver
phi_true = np.random.uniform(low=-1.0, high=1.0, size=N) 
macsum_true = Macsum(N,phi_true)
print(f"True Kernel : {phi_true}")
# Out:
# True Kernel : [-0.81251159 -0.86656395]

# %%
def generate_data_for_macsum(
    macsum, 
    phi_true,
    n_samples: int, 
    noise_level: float = 0.01,
    borne: int = 50.0
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Génère un jeu de données (X, Y) qui suit la logique du modèle Macsum.
    CORRIGÉE : y_inside est maintenant bien généré à l'intérieur de l'intervalle.
    """
    n = len(phi_true)
    n_samples= int(n_samples * 1.1)
    
    X  = np.random.uniform(low=-borne, high=borne, size=(n_samples,n))
    Y = np.zeros(n_samples)

    for i in range(n_samples):
        x = X[i]

        y_lower_true, y_upper_true = macsum.prediction(x)
        
        
        y_inside = (y_upper_true + y_lower_true)/2
        
        # 3. Ajouter un peu de bruit de mesure (gaussien) pour plus de réalisme.
        interval_spread = y_upper_true - y_lower_true
        if interval_spread < 1e-6:
             interval_spread = 1.0 # Éviter la division par zéro
             
        noise = np.random.randn() * noise_level * interval_spread
        
        Y[i] = y_inside + noise

    eval_index = int(n_samples*0.1)
    return X[eval_index:], Y[eval_index:], X[:eval_index], Y[:eval_index]

# %%
def save_data(X,Y,name="data"):

    # Convertir la matrice numpy en DataFrame
    label = [ f"x{i}"for i in range( X.shape[1])]
    label.insert(-1,"target")
    df = pd.DataFrame(np.column_stack((X, Y)), columns=label)

    # Sauvegarder dans CSV
    df.to_csv(name+'.csv', index=False)

# %%
X,Y,X_eval,Y_eval = generate_data_for_macsum( macsum_true,phi_true,1000,borne=50)
print(X_eval,Y_eval)
# Out:
# [[-21.81605084 -47.27390615]
#  [  8.96327028  -5.03620681]
#  [ -3.33577351  25.08667154]
#  [ 22.48293811  37.5189526 ]
#  [ 43.79390741  49.46915267]
#  [-29.99635165 -46.6797233 ]
#  [ 23.68550501  30.3953187 ]
#  [  9.21567686   6.6315601 ]
#  [ 19.65091009 -46.28772348]
#  [ 22.74815694 -33.88296375]
#  [ 36.49116747  30.84985424]
#  [-35.08778802   3.03432842]
#  [-36.3379773   41.19849365]
#  [  9.08558609  36.99411573]
#  [ 37.2715996   15.41371011]
#  [ -8.13074636  43.28122355]
#  [ -7.86817363 -10.30600743]
#  [  8.11576072 -21.68926188]
#  [  9.68958098 -19.62029801]
#  [ 11.69526049  18.63654317]
#  [-21.18023966  -0.64736968]
#  [ -6.18122078 -38.28280817]
#  [-18.86028147 -39.48604695]
#  [-34.6702214   14.65426839]
#  [  3.41229781  23.00449307]
#  [ 20.19918843  28.34302429]
#  [-32.22422046  46.91388808]
#  [  0.88921058 -44.38611674]
#  [ 36.78633369 -13.21511189]
#  [-28.35290693  20.08719971]
#  [ 27.77819974 -15.83123411]
#  [-44.31212156  35.95791704]
#  [ 31.79439931 -40.78228332]
#  [-26.59181472   9.20882837]
#  [ 41.34462995 -43.84355338]
#  [-42.9385093  -23.08545447]
#  [ 23.06229077   9.79357271]
#  [  2.09675821 -12.0817659 ]
#  [ 46.43993944   9.87742458]
#  [-24.56988756 -32.27646288]
#  [-24.6174175  -10.38362923]
#  [ 14.61350581 -24.89034872]
#  [-26.38766291   3.69116455]
#  [ 45.61842352 -35.54226154]
#  [ -5.20367543  17.56958048]
#  [ -5.05334243 -17.51482437]
#  [-40.17824049  41.14168137]
#  [-48.14211433  -2.68762306]
#  [-28.66755609  44.61963448]
#  [-13.27828601  11.9793705 ]
#  [ 37.33064481 -26.81882193]
#  [ -6.0588882   43.0040191 ]
#  [ 47.01115518  23.29740006]
#  [ 22.99757607  24.52778423]
#  [-28.68741348  42.09894623]
#  [-21.43586462   0.11420208]
#  [ 41.23070972 -31.13011645]
#  [-30.58246227 -45.87432369]
#  [ -4.60927997  16.17243033]
#  [ 31.56822734  31.56803983]
#  [  7.11935341 -23.70745668]
#  [-20.02711309 -10.65099422]
#  [ 29.36790963  24.21857196]
#  [-44.20137955  -7.45546871]
#  [ 13.13250149 -40.74829706]
#  [ 32.74247219  31.41714796]
#  [  6.07316782 -49.56944392]
#  [-13.02267598 -18.60584414]
#  [-25.17385657  33.72323952]
#  [ 37.08018429  19.66135531]
#  [ 26.2792664   23.63969206]
#  [-35.94245318 -31.17485975]
#  [ -2.85566479  -7.91146109]
#  [ 37.87992884  49.39294133]
#  [ 19.13226244  30.45397754]
#  [ 14.30097958 -13.58071961]
#  [-46.84633088   2.87873811]
#  [-24.97192803   5.23248657]
#  [  8.69082769   4.57778069]
#  [ 30.74426644  19.19436547]
#  [ -0.65685204 -17.19226388]
#  [  7.11777067  11.87447616]
#  [ 49.4272766   39.8958265 ]
#  [-14.40538646  -9.01230036]
#  [ -2.82268784  25.38421917]
#  [ 13.46692381 -17.82235896]
#  [ 35.4115727   14.91671753]
#  [ 46.6056597  -22.309088  ]
#  [  7.59498748  21.22630272]
#  [  2.90556609 -16.13541049]
#  [ -6.03873447 -47.64211118]
#  [ 20.45699363 -32.69716361]
#  [ 24.87843121  -8.28663575]
#  [ -9.64707848  18.36184531]
#  [-43.11829345 -16.86076561]
#  [-23.88485057  44.77837154]
#  [-40.26508865  20.77157726]
#  [ 14.49076537 -47.07893284]
#  [ 38.38955445  -4.35386819]
#  [ 41.89998953   7.67248213]
#  [-48.36597628 -43.53322702]
#  [-32.7733591   12.40031265]
#  [-16.76955587  13.00209837]
#  [ 14.97445531  12.75257198]
#  [ -2.400298   -47.91470422]
#  [ -7.68733773  19.30835476]
#  [ 27.53527169 -31.10412569]
#  [ -9.09355721 -25.65135913]
#  [  5.39687123 -42.86641552]
#  [ -6.32579539 -48.46545971]] [ 29.01669263  -1.11588878  -9.63261117 -24.96369639 -38.03090086
#   31.57947486 -22.13306777  -6.38071261  12.81588547   5.81052254
#  -27.17719093  11.81190321  -4.05020467 -19.464866   -20.85168194
#  -15.7422473    7.4495447    6.07515393   4.88616577 -12.53845281
#    8.35481596  19.18889939  23.89596916   6.11734485 -11.48280971
#  -20.04841604  -8.68136061  19.75643818  -7.84330399   2.4834461
#   -3.43822074   1.37920647   4.9037488    5.75716544   3.85993037
#   26.41415299 -12.97359399   4.45015126 -22.44820068  23.31575118
#   13.70516838   5.55984216   8.58220656  -2.63620692  -5.13863357
#    9.62840819  -2.46856721  18.99518809  -8.32255046  -0.55498648
#   -3.58487842 -16.72629579 -27.69486562 -19.35324244  -7.93329773
#    8.14571089  -2.10926389  31.61313478  -5.3750867  -25.6494722
#    7.57132843  12.31596176 -21.68513251  19.986949    12.19091396
#  -26.0393777   19.21860271  12.98289901  -5.10611097 -22.42763767
#  -20.19643678  27.18862647   4.45325038 -35.73752631 -20.58859775
#    0.44254654  15.43668514   7.06628275  -5.23829958 -19.91289419
#    7.72614497  -7.82065763 -36.05467993   9.43879012 -10.73318037
#    2.38352296 -19.97523323  -8.80122361 -11.99946722   5.74173483
#   22.70737715   6.71421005  -6.11864515  -3.9223781   23.17421195
#  -10.61602796   5.9204434   15.1530284  -12.42656037 -19.01579664
#   37.23691156   6.87496244   0.75793795 -11.18527883  22.25732976
#   -5.61896022   2.91490312  14.63366287  16.4319125   22.98151025]

# %% [markdown]
# ## Entrainement

# %% [markdown]
# ### Moindres carrés pour un noyau initial

# %%
initial_phi, _, _, _ = np.linalg.lstsq(X, Y, rcond=None)
print(initial_phi)
# Out:
# [-0.37962828 -0.43286018]

# %%
macsum = Macsum(N,initial_phi)
evaluate_model(X,Y,macsum)
# Out:
# {'containment_rate': 0.49797979797979797,
#  'avg_distance_to_interval': 7.269112903676498,
#  'avg_loss': 308.48676887213395,
#  'avg_interval_spread': 14.318582920137446}

# %%
macsum = Macsum(N)
macsum.fit(X,Y,X_eval,Y_eval,n_iteration=1000,alpha=1e-2,epsilon=1e-4)
# Out:
# Entraînement ::   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 2
#       1 macsum = Macsum(N)
# ----> 2 macsum.fit(X,Y,X_eval,Y_eval,n_iteration=1000,alpha=1e-2,epsilon=1e-4)
#
# File ~/Documents/GitHub/Macsum-aggregation-learning---Stage-LIP6--/MacsumAggregationLearning.py:184, in Macsum.fit(self, X, Y, X_eval, Y_eval, alpha, n_iteration, epsilon)
#     181 self.M = X.shape[0]
#     183 for i in trange(n_iteration,desc="Entraînement :"):
# --> 184     grd, loss = self.gradient(X,Y)
#     185     new_phi = self.phi - alpha*grd
#     187     if np.linalg.norm(self.phi-new_phi) < epsilon:
#
# File ~/Documents/GitHub/Macsum-aggregation-learning---Stage-LIP6--/MacsumAggregationLearning.py:116, in Macsum.gradient(self, X, Y)
#     113 all_gradients = (self._gradient_function(X[i], Y[i], all_prediction[i]) for i in range(self.M))
#     115 loss = np.sum( self._loss(Y[i],all_prediction[i]) for i in range(self.M))
# --> 116 return np.sum(list(all_gradients), axis=0)  / self.M, loss /self.M
#
# File ~/Documents/GitHub/Macsum-aggregation-learning---Stage-LIP6--/MacsumAggregationLearning.py:113, in <genexpr>(.0)
#     110 # implementation of 5.2.2. Gradient descent p.15
#     112 all_prediction = [ self.prediction(x) for x in X]
# --> 113 all_gradients = (self._gradient_function(X[i], Y[i], all_prediction[i]) for i in range(self.M))
#     115 loss = np.sum( self._loss(Y[i],all_prediction[i]) for i in range(self.M))
#     116 return np.sum(list(all_gradients), axis=0)  / self.M, loss /self.M
#
# AttributeError: 'Macsum' object has no attribute '_gradient_function'

# %%
plot_metrics(macsum.history)
evaluate_model(X,Y,macsum)

# %%
macsum =  Macsum(N)
macsum.fit_adam(X,Y,X_eval,Y_eval,n_epochs=2000,learning_rate=1e-4,epsilon_conv=1e-5,batch_size=64)
# Out:
# Début de l'entraînement avec l'optimiseur Adam...
# Entraînement Adam: 100%|██████████| 2000/2000 [01:22<00:00, 24.17it/s]
# Entraînement terminé (nombre maximum d'époques atteint).
# array([-0.68437563, -0.68435668])

# %%
plot_metrics(macsum.history)
evaluate_model(X,Y,macsum)
# Out:
# {'containment_rate': 0.8292929292929293,
#  'avg_distance_to_interval': 9.686343830602189,
#  'avg_loss': 404.6212419066833,
#  'avg_interval_spread': 22.63846305665556}

# %%
macsum_sigmoide =  Macsum_sigmoide(N,alpha=0.1,gamma=0.6,k_sigmoid=0.01)
macsum_sigmoide.fit_adam(X,Y,X_eval,Y_eval,n_epochs=5000,learning_rate=1e-4,epsilon_conv=1e-6,batch_size=128,beta1=0.7,beta2=0.99)
# Out:
# Début de l'entraînement avec l'optimiseur Adam...
# Entraînement Adam: 100%|██████████| 5000/5000 [03:42<00:00, 22.47it/s]
# Entraînement terminé (nombre maximum d'époques atteint).
# array([-0.80409871, -0.80412008])

# %%
plot_metrics(macsum_sigmoide.history)
evaluate_model(X,Y,macsum_sigmoide)
# Out:
# {'containment_rate': 0.9888888888888889,
#  'avg_distance_to_interval': 12.403300681674478,
#  'avg_loss': 539.6647035304762,
#  'avg_interval_spread': 26.59948985082443}

# %%
print(np.linalg.norm(macsum.phi-phi_true))
print(np.linalg.norm(macsum_sigmoide.phi-phi_true))
# Out:
# 0.2647195251691647
# 0.261740254766316

# %%
save_data(X,Y,"train_simoide_classique")
save_data(X_eval,Y_eval,"test_simoide_classique")
